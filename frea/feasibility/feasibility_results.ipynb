# %%
# %run plot_feasibility.py
# Out:
# >> ----------------------------------------
# >> Logging to /home/currychen/Project/FREA/frea/feasibility/train_log/min_dis_threshold_0.1_seed0/Scenario9_Town05
# >> ----------------------------------------
# >> Loading Safety network HJR from model.HJR.2000000.torch
# >> -------------------- Reading learning curve data --------------------
