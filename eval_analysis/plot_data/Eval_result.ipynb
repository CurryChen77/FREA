# %%
run plot_evaluation_result.py
# Out:
# >> ---------- collision ratio ----------
# >> AV:Expert CBV:PPO in Scenario9_Town02: 20.0
# >> AV:Expert CBV:PPO in Scenario9_Town05: 22.5
# >> AV:Expert CBV:FREA in Scenario9_Town02: 11.43
# >> AV:Expert CBV:FREA in Scenario9_Town05: 5.0
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town02: 31.43
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town05: 38.75
# >> ---------- collision ratio ----------
# >> ---------- feasibility boundary mean distance (m) ----------
# >> AV:Expert CBV:PPO in Scenario9_Town02: 7.25
# >> AV:Expert CBV:PPO in Scenario9_Town05: 5.53
# >> AV:Expert CBV:FREA in Scenario9_Town02: 4.65
# >> AV:Expert CBV:FREA in Scenario9_Town05: 1.54
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town02: 3.17
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town05: 7.91
# >> ---------- feasibility boundary mean distance (m) ----------
# >> ---------- near-miss unfeasible ratio ----------
# >> AV:Expert CBV:PPO in Scenario9_Town02: 62.11
# >> AV:Expert CBV:PPO in Scenario9_Town05: 41.94
# ...
