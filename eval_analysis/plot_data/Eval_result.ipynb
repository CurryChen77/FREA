# %%
run plot_evaluation_result.py
# Out:
# >> ---------- collision ratio ----------
# >> AV:Expert CBV:PPO in Scenario9_Town02: 30.0
# >> AV:Expert CBV:PPO in Scenario9_Town05: 37.5
# >> AV:Expert CBV:FREA in Scenario9_Town02: 5.71
# >> AV:Expert CBV:FREA in Scenario9_Town05: 5.0
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town02: 24.29
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town05: 11.25
# >> ---------- collision ratio ----------
# >> ---------- feasibility boundary mean distance (m) ----------
# >> AV:Expert CBV:PPO in Scenario9_Town02: 7.58
# >> AV:Expert CBV:PPO in Scenario9_Town05: 8.53
# >> AV:Expert CBV:FREA in Scenario9_Town02: 2.87
# >> AV:Expert CBV:FREA in Scenario9_Town05: 7.42
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town02: 6.56
# >> AV:Expert CBV:FPPO-RS in Scenario9_Town05: 10.69
# >> ---------- feasibility boundary mean distance (m) ----------
# >> ---------- near-miss unfeasible ratio ----------
# >> AV:Expert CBV:PPO in Scenario9_Town02: 68.54
# >> AV:Expert CBV:PPO in Scenario9_Town05: 45.32
# ...
