# %%
run plot_evaluation_result.py --overload --show
# Out:
# >> --------------Processing eval_cbv_pretrained_with_expert--------------
# >> --------------------Collision Ratio (%)--------------------
# >> AV:PlanT  CBV:PPO in Scenario9_Town02: 37.14
# >> AV:PlanT  CBV:PPO in Scenario9_Town05: 52.5
# >> AV:Expert  CBV:PPO in Scenario9_Town02: 30.0
# >> AV:Expert  CBV:PPO in Scenario9_Town05: 37.5
# >> AV:Expert  CBV:FREA in Scenario9_Town02: 5.71
# >> AV:Expert  CBV:FREA in Scenario9_Town05: 5.0
# >> AV:PlanT  CBV:FPPO-RS in Scenario9_Town02: 34.29
# >> AV:PlanT  CBV:FPPO-RS in Scenario9_Town05: 27.5
# >> AV:Expert  CBV:FPPO-RS in Scenario9_Town02: 24.29
# >> AV:Expert  CBV:FPPO-RS in Scenario9_Town05: 11.25
# >> AV:PlanT  CBV:FREA in Scenario9_Town02: 5.71
# >> AV:PlanT  CBV:FREA in Scenario9_Town05: 10.0
# >> --------------------Collision Ratio (%)--------------------
# >> --------------------Infeasible Ratio (%)--------------------
# >> AV:PlanT  CBV:PPO in Scenario9_Town02: 41.98
# >> AV:PlanT  CBV:PPO in Scenario9_Town05: 34.42
# ...

# %%
run ../King_analysis/King_analysis.py
# Out:
# >> ----------------------------------------
# >> Logging to /home/currychen/Project/FREA/eval_analysis/King_analysis
# >> ----------------------------------------
# >> Loading Safety network HJR from model.HJR.2000000.torch
# >> Successfully loading the feasibility policy
# Processing agents_1
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 82/82 [00:06<00:00, 12.33it/s]
# Processing agents_4
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 82/82 [00:09<00:00,  8.60it/s]
# Processing agents_2
# ...
